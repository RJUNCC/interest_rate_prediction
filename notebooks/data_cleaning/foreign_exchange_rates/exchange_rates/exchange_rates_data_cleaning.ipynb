# %%
import pandas as pd
import joblib
from pathlib import Path
import os
import sys
import time
notebook_dir = os.path.dirname(os.path.abspath(''))
src_path = os.path.join(notebook_dir, '..\..\..\src')
sys.path.append(src_path)
print(src_path)
# Out:
# d:\ANNACONDA\projects\interest_rate_prediction\notebooks\data_cleaning\foreign_exchange_rates\..\..\..\src

# %%
os.getcwd()
# Out:
# 'd:\\ANNACONDA\\projects\\interest_rate_prediction\\notebooks\\data_cleaning\\foreign_exchange_rates\\exchange_rates'

# %%
from config import CSV_DATA_PATH

# %%
bill_rates = pd.read_csv(f"../../../{CSV_DATA_PATH}bill_rates.csv")
bill_rates
# Out:
#           Date  4 WEEKS BANK DISCOUNT  4 WEEKS COUPON EQUIVALENT  \
# 0     12/29/23                   5.33                       5.44
# 1     12/28/23                   5.31                       5.42
# 2     12/27/23                   5.28                       5.39
# 3     12/26/23                   5.27                       5.38
# 4     12/22/23                   5.27                       5.38
# ...        ...                    ...                        ...
# 5500    1/8/02                   1.67                       1.69
# 5501    1/7/02                   1.68                       1.71
# 5502    1/4/02                   1.69                       1.72
# 5503    1/3/02                   1.70                       1.73
# 5504    1/2/02                   1.71                       1.74
#
#       8 WEEKS BANK DISCOUNT  8 WEEKS COUPON EQUIVALENT  \
# 0                      5.33                       5.46
# 1                      5.29                       5.42
# ...

# %%
bill_rates["Date"]  = pd.to_datetime(bill_rates["Date"], format="%m/%d/%y")
bill_rates["Year"]  = bill_rates["Date"].dt.year
bill_rates["Month"] = bill_rates["Date"].dt.month
bill_rates["Day"]   = bill_rates["Date"].dt.day
bill_rates = bill_rates.drop("Date", axis=1)

# %%
bill_rates
# Out:
#       4 WEEKS BANK DISCOUNT  4 WEEKS COUPON EQUIVALENT  8 WEEKS BANK DISCOUNT  \
# 0                      5.33                       5.44                   5.33
# 1                      5.31                       5.42                   5.29
# 2                      5.28                       5.39                   5.29
# 3                      5.27                       5.38                   5.27
# 4                      5.27                       5.38                   5.26
# ...                     ...                        ...                    ...
# 5500                   1.67                       1.69                    NaN
# 5501                   1.68                       1.71                    NaN
# 5502                   1.69                       1.72                    NaN
# 5503                   1.70                       1.73                    NaN
# 5504                   1.71                       1.74                    NaN
#
# ...

# %%
bins   = [0, 3, 6, 8, 12]
labels = ["Q1", "Q2", "Q3", "Q4"]
bill_rates["Quarter"] = pd.cut(bill_rates["Month"], bins=bins, labels=labels, right=True)
bill_rates
# Out:
#       4 WEEKS BANK DISCOUNT  4 WEEKS COUPON EQUIVALENT  8 WEEKS BANK DISCOUNT  \
# 0                      5.33                       5.44                   5.33
# 1                      5.31                       5.42                   5.29
# 2                      5.28                       5.39                   5.29
# 3                      5.27                       5.38                   5.27
# 4                      5.27                       5.38                   5.26
# ...                     ...                        ...                    ...
# 5500                   1.67                       1.69                    NaN
# 5501                   1.68                       1.71                    NaN
# 5502                   1.69                       1.72                    NaN
# 5503                   1.70                       1.73                    NaN
# 5504                   1.71                       1.74                    NaN
#
# ...

# %%
path = Path(Path.cwd()/"../../../../data")
path
# Out:
# WindowsPath('d:/ANNACONDA/projects/interest_rate_prediction/notebooks/data_cleaning/market_indicators/bond_yields/../../../../data')

# %%
data_folder = path/'parquet/bonds_rates/bill_rates'
data_folder.mkdir(parents=True, exist_ok=True)

# %%
bill_rates.to_parquet(data_folder/"bill_rates.parquet")
